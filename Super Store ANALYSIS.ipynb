# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import warnings
import seaborn as sns
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
d=pd.read_excel(r"D:\kedar\excel\Sample - Superstore (1).xls")

# %%
#data=pd.read_csv(r"D:\Bengaluru_House_Data.csv")

# %%
d
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993    CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 0     ...       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2     ...       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...       33311   South  FUR-TA-10000577        Furniture       Tables
# 4     ...       33311   South  OFF-ST-10000760  Office Supplies      Storage
# ...   ...         ...     ...              ...              ...          ...
# 9989  ...       33180   South  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...       92627    West  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...       92627    West  TEC-PH-10003645       Technology       Phones
# 9992  ...       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 21 columns]

# %%
d.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
d.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# 9989       33180   South  FUR-FU-10001889        Furniture  Furnishings
# 9990       92627    West  FUR-FU-10000747        Furniture  Furnishings
# 9991       92627    West  TEC-PH-10003645       Technology       Phones
# 9992       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name    Sales  Quantity  \
# 9989                             Ultra Door Pull Handle   25.248         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.960         2
# 9991                              Aastra 57i VoIP phone  258.576         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# 9991       0.2  19.3932
# 9992       0.0  13.3200
# 9993       0.0  72.9480
#
# [5 rows x 21 columns]

# %%
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
d=pd.read_excel(r"D:\kedar\excel\Sample - Superstore (1).xls")

# %%
d

# %%
d.shape
# Out:
# (9994, 21)

# %%
d.columns

# %%
#to check is there any missing value
d.isnull()

# %%
d.isnull().sum()

# %%
d.isnull().sum().sum()

# %%
#head to show first 5 records
d.head()

# %%
#tail to show last 5 records
d.tail()

# %%
d.head(10)

# %%
d.tail(10)

# %%
#information of dataset
d.info()

# %%
#drop columns which not required
d.drop(['Row ID'],axis=1,inplace=True) #inplace true is for permanent

# %%
d

# %%
#print ststistical information
d.describe()

# %%
d.describe(include='all')

# %%
#to check any duplicate value
d.duplicated().sum()
# Out:
# 0

# %%
#rename column name
d.rename(columns={'Country/Region':'Country'},inplace=True)

# %%
d

# %%
#droping a column using variable assining
q=d.drop(['Order ID'],axis=1)

# %%
q

# %%
d

# %%
#random lines
d.sample(4)

# %%
#num of unique values
d.nunique()

# %%
#correlation ((-1) - 1)
d.corr()

# %%
#coverrance
d.cov()

# %%
d

# %%
#statistics figures for specific column
d['Sales'].count()
# Out:
# 9994

# %%
d['Sales'].max()
# Out:
# 22638.48

# %%
#to count number of categories
d['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
d['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
d['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
d
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993    CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 0     ...       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2     ...       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...       33311   South  FUR-TA-10000577        Furniture       Tables
# 4     ...       33311   South  OFF-ST-10000760  Office Supplies      Storage
# ...   ...         ...     ...              ...              ...          ...
# 9989  ...       33180   South  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...       92627    West  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...       92627    West  TEC-PH-10003645       Technology       Phones
# 9992  ...       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 21 columns]

# %%
d1=d.copy()
d1=d1.pivot_table('Profit',columns='Region',aggfunc='sum')
d1
# Out:
# Region     Central      East       South         West
# Profit  39706.3625  91522.78  46749.4303  108418.4489

# %%
d2=d.copy()
d2=d2.pivot_table('Sales',columns='Region',aggfunc='sum')
d1
# Out:
# Region      Central       East       South         West
# Sales   501239.8908  678781.24  391721.905  725457.8245

# %%
d3=d.copy()
d3=d3.pivot_table('Sales',columns='Region',aggfunc='max')
d1
# Out:
# Region      Central       East       South         West
# Sales   501239.8908  678781.24  391721.905  725457.8245

# %%
d4=d.copy()
d4
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993    CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 0     ...       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2     ...       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...       33311   South  FUR-TA-10000577        Furniture       Tables
# 4     ...       33311   South  OFF-ST-10000760  Office Supplies      Storage
# ...   ...         ...     ...              ...              ...          ...
# 9989  ...       33180   South  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...       92627    West  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...       92627    West  TEC-PH-10003645       Technology       Phones
# 9992  ...       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 21 columns]

# %%
d4['Sales']=d['Sales']*d['Quantity']
d4['Sales']
# Out:
# 0        523.9200
# 1       2195.8200
# 2         29.2400
# 3       4787.8875
# 4         44.7360
#           ...
# 9989      75.7440
# 9990     183.9200
# 9991     517.1520
# 9992     118.4000
# 9993     486.3200
# Name: Sales, Length: 9994, dtype: float64

# %%
d4
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993    CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 0     ...       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2     ...       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...       33311   South  FUR-TA-10000577        Furniture       Tables
# 4     ...       33311   South  OFF-ST-10000760  Office Supplies      Storage
# ...   ...         ...     ...              ...              ...          ...
# 9989  ...       33180   South  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...       92627    West  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...       92627    West  TEC-PH-10003645       Technology       Phones
# 9992  ...       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name      Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase   523.9200         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  2195.8200         3
# 2     Self-Adhesive Address Labels for Typewriters b...    29.2400         2
# 3         Bretford CR4500 Series Slim Rectangular Table  4787.8875         5
# 4                        Eldon Fold 'N Roll Cart System    44.7360         2
# ...                                                 ...        ...       ...
# 9989                             Ultra Door Pull Handle    75.7440         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   183.9200         2
# 9991                              Aastra 57i VoIP phone   517.1520         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   118.4000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...   486.3200         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 21 columns]

# %%
d4=d4.groupby(['Category'])['Sales'].sum()
d4=pd.DataFrame(d4)
d4
# Out:
#                         Sales
# Category
# Furniture        3.859215e+06
# Office Supplies  3.548585e+06
# Technology       4.080262e+06

# %%
n=d.groupby('Category').Sales.sum().sort_values(ascending=False)
n
# Out:
# Category
# Technology         836154.0330
# Furniture          741999.7953
# Office Supplies    719047.0320
# Name: Sales, dtype: float64

# %%
n=d.groupby('Sub-Category').Sales.sum().sort_values(ascending=False)
n
# Out:
# Sub-Category
# Phones         330007.0540
# Chairs         328449.1030
# Storage        223843.6080
# Tables         206965.5320
# Binders        203412.7330
# Machines       189238.6310
# Accessories    167380.3180
# Copiers        149528.0300
# Bookcases      114879.9963
# Appliances     107532.1610
# Furnishings     91705.1640
# Paper           78479.2060
# Supplies        46673.5380
# Art             27118.7920
# Envelopes       16476.4020
# Labels          12486.3120
# Fasteners        3024.2800
# Name: Sales, dtype: float64

# %%
pd.crosstab(d['Segment'],d['Region'])
# Out:
# Region       Central  East  South  West
# Segment
# Consumer        1212  1469    838  1672
# Corporate        673   877    510   960
# Home Office      438   502    272   571

# %%
d.sort_values(by=['Category'])
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 8133    8134  CA-2015-131352 2015-10-08 2015-10-13  Standard Class
# 1903    1904  CA-2017-167094 2017-10-21 2017-10-22     First Class
# 6151    6152  CA-2014-111871 2014-03-18 2014-03-21    Second Class
# 6153    6154  CA-2017-151484 2017-04-20 2017-04-23     First Class
# ...      ...             ...        ...        ...             ...
# 1844    1845  US-2017-113852 2017-07-29 2017-08-02  Standard Class
# 3921    3922  CA-2016-110044 2016-06-28 2016-07-02    Second Class
# 6173    6174  US-2014-106299 2014-08-02 2014-08-08  Standard Class
# 8348    8349  US-2015-115238 2015-04-30 2015-05-04  Standard Class
# 2522    2523  CA-2016-124352 2016-10-15 2016-10-21  Standard Class
#
#      Customer ID     Customer Name      Segment        Country           City  \
# 0       CG-12520       Claire Gute     Consumer  United States      Henderson
# 8133    GH-14485         Gene Hale    Corporate  United States         Dallas
# 1903    DK-12835   Damala Kotsonis    Corporate  United States    Springfield
# 6151    EK-13795     Eileen Kiefer  Home Office  United States  San Francisco
# 6153    CV-12805     Cynthia Voltz    Corporate  United States   Philadelphia
# ...          ...               ...          ...            ...            ...
# 1844    GW-14605  Giulietta Weimer     Consumer  United States        Seattle
# 3921    RF-19735      Roland Fjeld     Consumer  United States        Chicago
# 6173    NZ-18565     Nick Zandusky  Home Office  United States    Springfield
# 8348    JW-15220         Jane Waco    Corporate  United States       Lawrence
# 2522    CD-12790   Cynthia Delaney  Home Office  United States  Oklahoma City
#
#       ... Postal Code   Region       Product ID    Category Sub-Category  \
# 0     ...       42420    South  FUR-BO-10001798   Furniture    Bookcases
# 8133  ...       75081  Central  FUR-FU-10003708   Furniture  Furnishings
# 1903  ...       97477     West  FUR-CH-10000155   Furniture       Chairs
# 6151  ...       94110     West  FUR-BO-10004218   Furniture    Bookcases
# 6153  ...       19120     East  FUR-FU-10001876   Furniture  Furnishings
# ...   ...         ...      ...              ...         ...          ...
# 1844  ...       98115     West  TEC-AC-10003027  Technology  Accessories
# 3921  ...       60610  Central  TEC-PH-10001299  Technology       Phones
# 6173  ...       65807  Central  TEC-AC-10003237  Technology  Accessories
# 8348  ...        1841     East  TEC-PH-10001300  Technology       Phones
# 2522  ...       73120  Central  TEC-PH-10003442  Technology       Phones
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase   261.960         2
# 8133  Tenex Traditional Chairmats for Medium Pile Ca...    72.780         3
# 1903                Global Comet Stacking Armless Chair   478.480         2
# 6151  Bush Heritage Pine Collection 5-Shelf Bookcase...  1198.330        10
# 6153                          Computer Room Manger, 14"    51.968         2
# ...                                                 ...       ...       ...
# 1844   Imation 8GB Mini TravelDrive USB 2.0 Flash Drive    90.570         3
# 3921         Polycom CX300 Desktop Phone USB VoIP phone   359.976         3
# 6173                    Memorex Micro Travel Drive 4 GB    21.200         2
# 8348  iKross Bluetooth Portable Keyboard + Cell Phon...   209.500        10
# 2522      Samsung Replacement EH64AVFWE Premium Headset     5.500         1
#
#       Discount   Profit
# 0         0.00  41.9136
# 8133      0.60 -70.9605
# 1903      0.20  47.8480
# 6151      0.15  70.4900
# 6153      0.20  10.3936
# ...        ...      ...
# 1844      0.00  11.7741
# 3921      0.20  35.9976
# 6173      0.00   9.1160
# 8348      0.00  58.6600
# 2522      0.00   1.3750
#
# [9994 rows x 21 columns]

# %%
grouped=pd.DataFrame(d.groupby(['Ship Mode','Category','Sub-Category','State','Region'])['Quantity','Discount','Sales','Profit'].sum().reset_index())
grouped
# Out:
#            Ship Mode    Category Sub-Category        State   Region  Quantity  \
# 0        First Class   Furniture    Bookcases      Arizona     West        12
# 1        First Class   Furniture    Bookcases   California     West        47
# 2        First Class   Furniture    Bookcases     Colorado     West         6
# 3        First Class   Furniture    Bookcases  Connecticut     East         9
# 4        First Class   Furniture    Bookcases      Florida    South         3
# ...              ...         ...          ...          ...      ...       ...
# 1629  Standard Class  Technology       Phones         Utah     West         3
# 1630  Standard Class  Technology       Phones      Vermont     East         5
# 1631  Standard Class  Technology       Phones     Virginia    South        54
# 1632  Standard Class  Technology       Phones   Washington     West        66
# 1633  Standard Class  Technology       Phones    Wisconsin  Central        33
#
#       Discount      Sales     Profit
# 0         1.40   391.4490  -677.5613
# 1         1.65  7814.1265   719.8419
# 2         1.40   180.8730  -343.8369
# 3         0.00   638.8200   185.2578
# 4         0.20   314.3520   -15.7176
# ...        ...        ...        ...
# 1629      0.20    16.7760     1.6776
# 1630      0.00  1294.7500   336.6350
# 1631      0.00  7628.3600  2045.6680
# 1632      3.60  5536.0320   408.8088
# 1633      0.00  3465.2300   940.6137
#
# [1634 rows x 9 columns]

# %%
d_shipmode=d[['Ship Mode','Category','Quantity']].groupby(['Ship Mode','Category']).sum('Quantity')
d_shipmode
# Out:
#                                 Quantity
# Ship Mode      Category
# First Class    Furniture            1238
#                Office Supplies      3372
#                Technology           1083
# Same Day       Furniture             453
#                Office Supplies      1147
#                Technology            360
# Second Class   Furniture            1569
#                Office Supplies      4480
#                Technology           1374
# Standard Class Furniture            4768
#                Office Supplies     13907
#                Technology           4122

# %%
state_sales_d=pd.pivot_table(data=d[['State','Sales']],
                            index=['State'],
                            values='Sales',
                            aggfunc='max')

# %%
state_sales_d
# Out:
#                           Sales
# State
# Alabama                3040.000
# Arizona                1879.960
# Arkansas               1793.980
# California             8187.650
# Colorado               2549.985
# Connecticut            1133.350
# Delaware              10499.970
# District of Columbia   1379.920
# Florida               22638.480
# Georgia                6354.950
# Idaho                  1128.390
# Illinois               2799.960
# Indiana               17499.950
# Iowa                   1408.100
# Kansas                  360.380
# Kentucky               3080.000
# Louisiana              1665.620
# Maine                   437.850
# Maryland               2541.980
# Massachusetts          1737.180
# Michigan               9892.740
# Minnesota              9449.950
# Mississippi            2430.080
# Missouri               4899.930
# Montana                2999.950
# Nebraska               2479.960
# Nevada                 4535.976
# New Hampshire          2249.910
# New Jersey             9099.930
# New Mexico              883.840
# New York              11199.968
# North Carolina         7999.980
# North Dakota            704.760
# Ohio                   4499.985
# Oklahoma               1805.880
# Oregon                 1487.040
# Pennsylvania           8399.976
# Rhode Island           5399.910
# South Carolina         1690.040
# South Dakota            416.320
# Tennessee              2314.116
# Texas                  8159.952
# Utah                   1499.950
# Vermont                4404.900
# Virginia               8749.950
# Washington            13999.960
# West Virginia           673.344
# Wisconsin              2807.840
# Wyoming                1603.136

# %%
state_sales_d.sort_values(by='Sales',ascending=False).head(10)
# Out:
#                   Sales
# State
# Florida       22638.480
# Indiana       17499.950
# Washington    13999.960
# New York      11199.968
# Delaware      10499.970
# Michigan       9892.740
# Minnesota      9449.950
# New Jersey     9099.930
# Virginia       8749.950
# Pennsylvania   8399.976

# %%
state_profit_d=pd.pivot_table(data=d[['State','Profit']],
                            index=['State'],
                            values='Profit',
                            aggfunc='max')

state_profit_d.sort_values(by='Profit',ascending=False).head(10)
# Out:
#                  Profit
# State
# Indiana       8399.9760
# Washington    6719.9808
# Delaware      5039.9856
# Michigan      4946.3700
# Minnesota     4630.4755
# New York      3919.9888
# Georgia       3177.4750
# Virginia      2799.9840
# Rhode Island  2591.9568
# New Jersey    2365.9818

# %%
d_Category_sales=pd.pivot_table(data=d[['Category','Sub-Category','Sales']],
                            index=['Category','Sub-Category'],
                            values='Sales',
                            aggfunc='max')

d_Category_sales
# Out:
#                                   Sales
# Category        Sub-Category
# Furniture       Bookcases      4404.900
#                 Chairs         4416.174
#                 Furnishings    1336.440
#                 Tables         4297.644
# Office Supplies Appliances     2625.120
#                 Art            1113.024
#                 Binders        9892.740
#                 Envelopes       604.656
#                 Fasteners        93.360
#                 Labels          786.480
#                 Paper           733.950
#                 Storage        2934.330
#                 Supplies       8187.650
# Technology      Accessories    3347.370
#                 Copiers       17499.950
#                 Machines      22638.480
#                 Phones         4548.810

# %%
d_Category_quantity=pd.pivot_table(data=d[['Category','Sub-Category','Quantity']],
                            index=['Category','Sub-Category'],
                            values='Quantity',
                            aggfunc='sum')

d_Category_quantity
# Out:
#                               Quantity
# Category        Sub-Category
# Furniture       Bookcases          868
#                 Chairs            2356
#                 Furnishings       3563
#                 Tables            1241
# Office Supplies Appliances        1729
#                 Art               3000
#                 Binders           5974
#                 Envelopes          906
#                 Fasteners          914
#                 Labels            1400
#                 Paper             5178
#                 Storage           3158
#                 Supplies           647
# Technology      Accessories       2976
#                 Copiers            234
#                 Machines           440
#                 Phones            3289

# %%
#creating new column
d['Revenue']=d['Sales']-d['Profit']
d
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993    CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... Region       Product ID         Category Sub-Category  \
# 0     ...  South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...  South  FUR-CH-10000454        Furniture       Chairs
# 2     ...   West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...  South  FUR-TA-10000577        Furniture       Tables
# 4     ...  South  OFF-ST-10000760  Office Supplies      Storage
# ...   ...    ...              ...              ...          ...
# 9989  ...  South  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...   West  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...   West  TEC-PH-10003645       Technology       Phones
# 9992  ...   West  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...   West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name     Sales Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600        2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400        3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200        2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 4                        Eldon Fold 'N Roll Cart System   22.3680        2
# ...                                                 ...       ...      ...
# 9989                             Ultra Door Pull Handle   25.2480        3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600        2
# 9991                              Aastra 57i VoIP phone  258.5760        2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000        4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600        2
#
#       Discount    Profit    Revenue
# 0         0.00   41.9136   220.0464
# 1         0.00  219.5820   512.3580
# 2         0.00    6.8714     7.7486
# 3         0.45 -383.0310  1340.6085
# 4         0.20    2.5164    19.8516
# ...        ...       ...        ...
# 9989      0.20    4.1028    21.1452
# 9990      0.00   15.6332    76.3268
# 9991      0.20   19.3932   239.1828
# 9992      0.00   13.3200    16.2800
# 9993      0.00   72.9480   170.2120
#
# [9994 rows x 22 columns]

# %%
d
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993    CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 0     ...       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2     ...       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...       33311   South  FUR-TA-10000577        Furniture       Tables
# 4     ...       33311   South  OFF-ST-10000760  Office Supplies      Storage
# ...   ...         ...     ...              ...              ...          ...
# 9989  ...       33180   South  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...       92627    West  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...       92627    West  TEC-PH-10003645       Technology       Phones
# 9992  ...       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 21 columns]

# %%
d['GrossPrice']=(d['Revenue']-d['Profit'])/d['Quantity']

# %%
d.head(10)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5       6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6       7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7       8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8       9  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9      10  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 5  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 6  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 7  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 8  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 9  Brosina Hoffman   Consumer  United States      Los Angeles  ...
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
# 3  FUR-TA-10000577        Furniture       Tables
# 4  OFF-ST-10000760  Office Supplies      Storage
# 5  FUR-FU-10001487        Furniture  Furnishings
# 6  OFF-AR-10002833  Office Supplies          Art
# 7  TEC-PH-10002275       Technology       Phones
# 8  OFF-BI-10003910  Office Supplies      Binders
# 9  OFF-AP-10002892  Office Supplies   Appliances
#
#                                         Product Name     Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400        3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200        2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 4                     Eldon Fold 'N Roll Cart System   22.3680        2
# 5  Eldon Expressions Wood and Plastic Desk Access...   48.8600        7
# 6                                         Newell 322    7.2800        4
# 7                     Mitel 5320 IP Phone VoIP phone  907.1520        6
# 8  DXL Angle-View Binders with Locking Rings by S...   18.5040        3
# 9                   Belkin F5C206VTEL 6 Outlet Surge  114.9000        5
#
#   Discount    Profit    Revenue  GrossPrice
# 0     0.00   41.9136   220.0464     89.0664
# 1     0.00  219.5820   512.3580     97.5920
# 2     0.00    6.8714     7.7486      0.4386
# 3     0.45 -383.0310  1340.6085    344.7279
# 4     0.20    2.5164    19.8516      8.6676
# 5     0.00   14.1694    34.6906      2.9316
# 6     0.00    1.9656     5.3144      0.8372
# 7     0.20   90.7152   816.4368    120.9536
# 8     0.20    5.7825    12.7215      2.3130
# 9     0.00   34.4700    80.4300      9.1920
#
# [10 rows x 23 columns]

# %%
#plot a graph profit vs Quantity
plt.bar(d['Quantity'],d['Profit'])
plt.title('profit vs Quantity',fontsize=15,color='red')
plt.xlabel('Quantity ',fontsize=15)
plt.ylabel('Profit ',fontsize=15)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(18,5))
plt.bar('Sub-Category','Category',data=d,color='orange')
plt.show()

# %%
print(d['State'].value_counts())
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# Louisiana                 42
# South Carolina            42
# Nevada                    39
# Nebraska                  38
# New Mexico                37
# Iowa                      30
# New Hampshire             27
# Kansas                    24
# Idaho                     21
# Montana                   15
# South Dakota              12
# Vermont                   11
# District of Columbia      10
# Maine                      8
# North Dakota               7
# West Virginia              4
# Wyoming                    1
# Name: State, dtype: int64

# %%
plt.figure(figsize=(15,4))
sns.countplot(x=d['State'])
plt.xticks(rotation=90)
plt.show()

# %%
print(d['Sub-Category'].value_counts())
plt.figure(figsize=(10,6))
sns.countplot(x=d['Sub-Category'])
plt.xticks(rotation=90)
plt.show()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
plt.bar(d['Quantity'],d['Sales'],color='red')
plt.title('Sales Vs Quantity',fontsize=15,color='blue')
plt.xlabel('Quantity ',fontsize=15)
plt.ylabel('Sales ',fontsize=15)

plt.show()

# %%
sns.regplot(x='Quantity',y='Profit',data=d)
plt.show()

# %%
sns.countplot(x='Segment',data=d,palette='coolwarm')
plt.show()

# %%
plt.title('segment',fontsize=20)
d['Segment'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
plt.show()

# %%
sns.countplot(x='Category',data=d,palette='tab10')
plt.show()

# %%
d.groupby('Segment')[['Profit','Sales']].sum().plot.bar(color=['red','blue'],figsize=(8,5))
plt.ylabel('Profit/Loss and Sales')
plt.show()

# %%
plt.title('Region',fontsize=20)
d['Region'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.title('Segment wise Sales in each region')
sns.barplot(x='Region',y='Sales',data=d,hue='Segment',palette='coolwarm_r')
plt.xlabel('Region',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.title('Segment wise Sales in each region')
sns.barplot(x='Region',y='Sales',data=d,palette='coolwarm_r')
plt.xlabel('Region',fontsize=15)
plt.show()

# %%
d.groupby('Region')[['Profit','Sales']].sum().plot.bar(color=['green','orange'],figsize=(8,5))
plt.ylabel('Profit/loss and sales')
plt.show()

# %%
plt.figure(figsize=(15,12))
sns.countplot(x='State',data=d,palette='rocket_r',order=d['State'].value_counts().index)
plt.xlabel('States',fontsize=25)
plt.xticks(rotation=70)
plt.show()

# %%
n_data=['Sales','Quantity','Discount','Profit']
plt.figure(figsize=(10,5))
sns.heatmap(d[n_data].corr(),annot=True,fmt='.4f',cmap='coolwarm_r',center=0)
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.lineplot('Discount','Profit',data=d,color='r',label='Discount')
plt.legend()
plt.show()

# %%
d.hist(bins=20,figsize=(20,15),color='red')
plt.show()

# %%
sns.pairplot(d,hue='Category')
plt.show()
